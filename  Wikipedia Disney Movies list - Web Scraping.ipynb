# %% [markdown]
# # Wikipedia Disney Movies list - Web Scraping

# %% [markdown]
# ![](https://i.imgur.com/0EBdH19.jpg)

# %% [markdown]
# ## 1. Introduction :

# %% [markdown]
# ### 1.1. What is web scraping <a name="subparagraph1"></a>

# %% [markdown]
# Web scraping is the process of collecting structured web data in an automated fashion. Some of the main use cases of web scraping include price monitoring, price intelligence, news monitoring, lead generation, and market research among many others.
#
# In general, web data extraction is used by people and businesses who want to make use of the vast amount of publicly available web data to make smarter decisions.
#
# There are a number of tools and methods for performing web scraping; using network traffic, Scrappy, Selenium and Beautiful Soup are the most popular methods. Every method has its own advantage and drawbacks. In this project Beautiful Soup was used.

# %% [markdown]
# ### 1.2. Problem statement

# %% [markdown]
# Movies are hobby to consumers. However data related to these main players of the entertainment industry can be valuable in many aspects. Competitor's can see how other companie's investments have performerd, or how a specific director's movies perform on the market. Also it might be useful to see which actors bring more revenue to a movie.
#
# These use cases, makes data sets related to this industry valuable. That's why in this project we tried to scrape movies of Walt Disney Company on Wikipedia and get the main information on the movies produced by this company
#
# The Walt Disney Company, commonly known as Disney, is an American diversified multinational mass media and entertainment conglomerate headquartered at the Walt Disney Studios complex in Burbank, California.
#
# Disney was originally founded on October 16, 1923, by brothers Walt and Roy O. Disney as the Disney Brothers Cartoon Studio; it also operated under the names The Walt Disney Studio and Walt Disney Productions before officially changing its name to The Walt Disney Company in 1986. The company established itself as a leader in the American animation industry before diversifying into live-action film production, television, and theme parks.

# %% [markdown]
# ### 1.3. Tools used in this project

# %% [markdown]
# In this project, we are going to use Python as our coding language to scrape the Wikipedia pages.
# In Python, We will mainly use Requests library to get the information from the websites.
#
# Then we will use Beautiful Soup library to turn it into an BS object.
#
# Throughout the project we will use a knowledge of HTML in order to inspect the page and find the right tags
#
# Then the information that has been scrapped will be turned into a Pandas DataFrame and then
# we are going to save the file as CSV.

# %% [markdown]
# ## 2. Project Steps:

# %% [markdown]
# 1. Assessing the Disney Movies page on Wikipedia: https://en.wikipedia.org/wiki/List_of_Walt_Disney_Pictures_films
# 2. Scraping all the links to movies on Disney Movies Wikipedia and save it to a CSV file
# 3. Scraping Info-Box of a sample movie
# 4. Extracting all the Info-Boxes of all the movies on Disney Movies Wikipedia automatically (Putting it all together)
# 5. Saving all the scrapped information to a csv file

# %% [markdown]
# #### 2.1. Assessing the Disney Movies page on Wikipedia: https://en.wikipedia.org/wiki/List_of_Walt_Disney_Pictures_films

# %%
# Importing necessary libraries

from bs4 import BeautifulSoup as bs
import requests
import pandas as pd

# %%
# using requests library to get the info on the page 
r_main = requests.get ("https://en.wikipedia.org/wiki/List_of_Walt_Disney_Pictures_films")

# %%
# checking if the page has responded with no error
r_main.status_code
# Out:
# 200

# %%
# turning what we got from the page through request into a beautiful soup object
main_soup = bs(r_main.text, "html.parser")

# %% [markdown]
# we need to find all the links to the movies listed on the page .In order to do so, we should assess the page's html source
#
# So we are going to use the inspect option on browser to check a sample movie in the lists on the page.

# %% [markdown]
# ![](https://i.imgur.com/XTSibPE.jpg)

# %% [markdown]
# #### 2.2. Scraping all the links to movies on Disney Movies Wikipedia

# %% [markdown]
# From the above page, we can see that the href and title attributes are in the "i" and "a" tags,
# so we are going to get the info on these tags for all the movies

# %%
# getting info of i and a tags from the beautiful soup of the page
links = main_soup.select(".wikitable.sortable i a")

# %%
#checking for the length of it
len(links)
# Out:
# 454

# %%
#automating the process to get all the title and links to the movies 

link_dict = {}
for i in range(len(links)):
        dict_key = links[i].get("title")
        dict_value = "https://en.wikipedia.org" + links[i].get("href")
        link_dict[dict_key] = dict_value

# %%
# checking for the content of the dictionary created
link_dict
# Out:
# {'Academy Award Review of Walt Disney Cartoons': 'https://en.wikipedia.org/wiki/Academy_Award_Review_of_Walt_Disney_Cartoons',
#  'Snow White and the Seven Dwarfs (1937 film)': 'https://en.wikipedia.org/wiki/Snow_White_and_the_Seven_Dwarfs_(1937_film)',
#  'Pinocchio (1940 film)': 'https://en.wikipedia.org/wiki/Pinocchio_(1940_film)',
#  'Fantasia (1940 film)': 'https://en.wikipedia.org/wiki/Fantasia_(1940_film)',
#  'The Reluctant Dragon (1941 film)': 'https://en.wikipedia.org/wiki/The_Reluctant_Dragon_(1941_film)',
#  'Dumbo': 'https://en.wikipedia.org/wiki/Dumbo',
#  'Bambi': 'https://en.wikipedia.org/wiki/Bambi',
#  'Saludos Amigos': 'https://en.wikipedia.org/wiki/Saludos_Amigos',
#  'Victory Through Air Power (film)': 'https://en.wikipedia.org/wiki/Victory_Through_Air_Power_(film)',
#  'The Three Caballeros': 'https://en.wikipedia.org/wiki/The_Three_Caballeros',
#  'Make Mine Music': 'https://en.wikipedia.org/wiki/Make_Mine_Music',
#  'Song of the South': 'https://en.wikipedia.org/wiki/Song_of_the_South',
#  'Fun and Fancy Free': 'https://en.wikipedia.org/wiki/Fun_and_Fancy_Free',
#  'Melody Time': 'https://en.wikipedia.org/wiki/Melody_Time',
#  'So Dear to My Heart': 'https://en.wikipedia.org/wiki/So_Dear_to_My_Heart',
#  'The Adventures of Ichabod and Mr. Toad': 'https://en.wikipedia.org/wiki/The_Adventures_of_Ichabod_and_Mr._Toad',
#  'Cinderella (1950 film)': 'https://en.wikipedia.org/wiki/Cinderella_(1950_film)',
#  'Treasure Island (1950 film)': 'https://en.wikipedia.org/wiki/Treasure_Island_(1950_film)',
#  'Alice in Wonderland (1951 film)': 'https://en.wikipedia.org/wiki/Alice_in_Wonderland_(1951_film)',
#  'The Story of Robin Hood (film)': 'https://en.wikipedia.org/wiki/The_Story_of_Robin_Hood_(film)',
#  'Peter Pan (1953 film)': 'https://en.wikipedia.org/wiki/Peter_Pan_(1953_film)',
#  'The Sword and the Rose': 'https://en.wikipedia.org/wiki/The_Sword_and_the_Rose',
#  'The Living Desert': 'https://en.wikipedia.org/wiki/The_Living_Desert',
#  'Rob Roy: The Highland Rogue': 'https://en.wikipedia.org/wiki/Rob_Roy:_The_Highland_Rogue',
#  'The Vanishing Prairie': 'https://en.wikipedia.org/wiki/The_Vanishing_Prairie',
#  '20,000 Leagues Under the Sea (1954 film)': 'https://en.wikipedia.org/wiki/20,000_Leagues_Under_the_Sea_(1954_film)',
#  'Ride a Wild Pony': 'https://en.wikipedia.org/wiki/Ride_a_Wild_Pony',
#  'No Deposit, No Return': 'https://en.wikipedia.org/wiki/No_Deposit,_No_Return',
#  'Treasure of Matecumbe': 'https://en.wikipedia.org/wiki/Treasure_of_Matecumbe',
#  'Gus (1976 film)': 'https://en.wikipedia.org/wiki/Gus_(1976_film)',
#  'The Shaggy D.A.': 'https://en.wikipedia.org/wiki/The_Shaggy_D.A.',
#  'Freaky Friday (1976 film)': 'https://en.wikipedia.org/wiki/Freaky_Friday_(1976_film)',
#  'Escape from the Dark': 'https://en.wikipedia.org/wiki/Escape_from_the_Dark',
#  'The Many Adventures of Winnie the Pooh': 'https://en.wikipedia.org/wiki/The_Many_Adventures_of_Winnie_the_Pooh',
#  'A Tale of Two Critters': 'https://en.wikipedia.org/wiki/A_Tale_of_Two_Critters',
#  'The Rescuers': 'https://en.wikipedia.org/wiki/The_Rescuers',
#  'Herbie Goes to Monte Carlo': 'https://en.wikipedia.org/wiki/Herbie_Goes_to_Monte_Carlo',
#  "Pete's Dragon (1977 film)": 'https://en.wikipedia.org/wiki/Pete%27s_Dragon_(1977_film)',
#  'Candleshoe': 'https://en.wikipedia.org/wiki/Candleshoe',
#  'Return from Witch Mountain': 'https://en.wikipedia.org/wiki/Return_from_Witch_Mountain',
#  'The Cat from Outer Space': 'https://en.wikipedia.org/wiki/The_Cat_from_Outer_Space',
#  'Hot Lead and Cold Feet': 'https://en.wikipedia.org/wiki/Hot_Lead_and_Cold_Feet',
#  'The North Avenue Irregulars': 'https://en.wikipedia.org/wiki/The_North_Avenue_Irregulars',
#  'The Apple Dumpling Gang Rides Again': 'https://en.wikipedia.org/wiki/The_Apple_Dumpling_Gang_Rides_Again',
#  'Unidentified Flying Oddball': 'https://en.wikipedia.org/wiki/Unidentified_Flying_Oddball',
#  'The Black Hole': 'https://en.wikipedia.org/wiki/The_Black_Hole',
#  'The Omega Connection': 'https://en.wikipedia.org/wiki/The_Omega_Connection',
#  'Midnight Madness (1980 film)': 'https://en.wikipedia.org/wiki/Midnight_Madness_(1980_film)',
#  'The Watcher in the Woods (1980 film)': 'https://en.wikipedia.org/wiki/The_Watcher_in_the_Woods_(1980_film)',
#  'Herbie Goes Bananas': 'https://en.wikipedia.org/wiki/Herbie_Goes_Bananas',
#  "The Last Flight of Noah's Ark": 'https://en.wikipedia.org/wiki/The_Last_Flight_of_Noah%27s_Ark',
#  'Popeye (film)': 'https://en.wikipedia.org/wiki/Popeye_(film)',
#  'The Devil and Max Devlin': 'https://en.wikipedia.org/wiki/The_Devil_and_Max_Devlin',
#  'Amy (1981 film)': 'https://en.wikipedia.org/wiki/Amy_(1981_film)',
#  'Dragonslayer (1981 film)': 'https://en.wikipedia.org/wiki/Dragonslayer_(1981_film)',
#  'The Fox and the Hound': 'https://en.wikipedia.org/wiki/The_Fox_and_the_Hound',
#  'Condorman': 'https://en.wikipedia.org/wiki/Condorman',
#  'Night Crossing': 'https://en.wikipedia.org/wiki/Night_Crossing',
#  'Toy Story 4': 'https://en.wikipedia.org/wiki/Toy_Story_4',
#  'The Lion King (2019 film)': 'https://en.wikipedia.org/wiki/The_Lion_King_(2019_film)',
#  'Maleficent: Mistress of Evil': 'https://en.wikipedia.org/wiki/Maleficent:_Mistress_of_Evil',
#  'Lady and the Tramp (2019 film)': 'https://en.wikipedia.org/wiki/Lady_and_the_Tramp_(2019_film)',
#  'Noelle (2019 film)': 'https://en.wikipedia.org/wiki/Noelle_(2019_film)',
#  'Frozen II': 'https://en.wikipedia.org/wiki/Frozen_II',
#  'Togo (film)': 'https://en.wikipedia.org/wiki/Togo_(film)',
#  'Timmy Failure: Mistakes Were Made': 'https://en.wikipedia.org/wiki/Timmy_Failure:_Mistakes_Were_Made',
#  'Onward (film)': 'https://en.wikipedia.org/wiki/Onward_(film)',
#  'Stargirl (film)': 'https://en.wikipedia.org/wiki/Stargirl_(film)',
#  'Dolphin Reef (film)': 'https://en.wikipedia.org/wiki/Dolphin_Reef_(film)',
#  'Elephant (2020 film)': 'https://en.wikipedia.org/wiki/Elephant_(2020_film)',
#  'Artemis Fowl (film)': 'https://en.wikipedia.org/wiki/Artemis_Fowl_(film)',
#  'Hamilton (2020 film)': 'https://en.wikipedia.org/wiki/Hamilton_(2020_film)',
#  'Black Is King': 'https://en.wikipedia.org/wiki/Black_Is_King',
#  'Magic Camp (film)': 'https://en.wikipedia.org/wiki/Magic_Camp_(film)',
#  'The One and Only Ivan (film)': 'https://en.wikipedia.org/wiki/The_One_and_Only_Ivan_(film)',
#  'Mulan (2020 film)': 'https://en.wikipedia.org/wiki/Mulan_(2020_film)',
#  'Godmothered': 'https://en.wikipedia.org/wiki/Godmothered',
#  'Safety (2020 film)': 'https://en.wikipedia.org/wiki/Safety_(2020_film)',
#  'Soul (2020 film)': 'https://en.wikipedia.org/wiki/Soul_(2020_film)',
#  'Flora & Ulysses (film)': 'https://en.wikipedia.org/wiki/Flora_%26_Ulysses_(film)',
#  'Raya and the Last Dragon': 'https://en.wikipedia.org/wiki/Raya_and_the_Last_Dragon',
#  'Cruella (film)': 'https://en.wikipedia.org/wiki/Cruella_(film)',
#  'Luca (2021 film)': 'https://en.wikipedia.org/wiki/Luca_(2021_film)',
#  'Jungle Cruise (film)': 'https://en.wikipedia.org/wiki/Jungle_Cruise_(film)',
#  'Encanto (film)': 'https://en.wikipedia.org/wiki/Encanto_(film)',
#  'Turning Red': 'https://en.wikipedia.org/wiki/Turning_Red',
#  'Disenchanted (film)': 'https://en.wikipedia.org/wiki/Disenchanted_(film)',
#  'Peter Pan & Wendy': 'https://en.wikipedia.org/wiki/Peter_Pan_%26_Wendy',
#  'The Little Mermaid (upcoming film)': 'https://en.wikipedia.org/wiki/The_Little_Mermaid_(upcoming_film)',
#  'Shrunk (film)': 'https://en.wikipedia.org/wiki/Shrunk_(film)',
#  "Chip 'n Dale: Rescue Rangers (film)": 'https://en.wikipedia.org/wiki/Chip_%27n_Dale:_Rescue_Rangers_(film)',
#  'Pinocchio (upcoming Disney film)': 'https://en.wikipedia.org/wiki/Pinocchio_(upcoming_Disney_film)',
#  'Hollywood Stargirl': 'https://en.wikipedia.org/wiki/Hollywood_Stargirl',
#  'Tim Federle': 'https://en.wikipedia.org/wiki/Tim_Federle#Fiction'}

# %% [markdown]
# we are going to save this dictionary into a CSV file

# %%
#turning the dictionary into a dataframe to easily save it to csv file
link_dict_df = pd.DataFrame(list(link_dict.items()),columns=['movie_name', 'movie_url'])

# %%
# saving the dictionary into a csv file
link_dict_df.to_csv("Disney_links.csv", index = False)

# %% [markdown]
# #### 2.3. Scraping Info-Box of a sample movie

# %% [markdown]
# Now that we have got the links to all disney movies we need to scrape these links
# in order to get the info-box of every movie page
#
# The info-boxes looks like this:

# %% [markdown]
# ![](https://i.imgur.com/790h6Be.png)

# %% [markdown]
# We want to scrape this info box for all the disney movis
# In order to get the familiar with the HTML tags We will scrape a sample one and then we will go for automating it .

# %%
# using requests library to get the info on the page 

r = requests.get ("https://en.wikipedia.org/wiki/Toy_Story_3")

# %%
# checking if the page has responded with no error
r.status_code
# Out:
# 200

# %%
# turning what we got from the page through request into a beautiful soup object

soup2 = bs (r.text, "html.parser")

# %% [markdown]
# We need to find the HTML tags related to the info-box of the page.In order to do so, we need to assess the page's html source
#
# So I am going to use the inspect option on browser to check the info-box on the page.

# %% [markdown]
# ![](https://i.imgur.com/dJuLgw3.jpg)

# %% [markdown]
# As it shows in the above picture the info box has its own class and all the info are stored in a tbody tag and each info is stored in a tr tag so we are going to scrape the infobox based on these findings

# %%
#getting info of the class infobox
t_tags = soup2.find_all ("table" , {"class": "infobox vevent"})
#getting info of tbody tag
tbody_tags = t_tags[0].find("tbody")
#getting info of all tr tags
tr_tags = tbody_tags.find_all("tr")

# %%
# check the number of the tr tags
len(tr_tags)
# Out:
# 18

# %%
# a for loop to get the infobox informations
# the first one is the title which has a different format and is put into the dictionary alone
# then its the image which we don't want so we start the for loop on number 2
movie_info = {}
movie_info["title"] = tr_tags[0].text
for i in range(2, len(tr_tags)) :
    content_key = tr_tags[i].find("th").get_text(" ", strip = True)
    content_value = tr_tags[i].find("td").get_text(" ", strip = True).replace("\xa0", " ").split("\n")
    movie_info [content_key] = content_value

# %%
# infobox for one movie
movie_info
# Out:
# {'title': 'Toy Story 3',
#  'Directed by': ['Lee Unkrich'],
#  'Screenplay by': ['Michael Arndt'],
#  'Story by': ['John Lasseter Andrew Stanton Lee Unkrich'],
#  'Produced by': ['Darla K. Anderson'],
#  'Starring': ['Tom Hanks Tim Allen Joan Cusack Don Rickles Wallace Shawn John Ratzenberger Estelle Harris Ned Beatty Michael Keaton Jodi Benson John Morris'],
#  'Cinematography': ['Jeremy Lasky Kim White'],
#  'Edited by': ['Ken Schretzmann'],
#  'Music by': ['Randy Newman'],
#  'Production companies': ['Walt Disney Pictures Pixar Animation Studios'],
#  'Distributed by': ['Walt Disney Studios Motion Pictures'],
#  'Release date': ['June 12, 2010 ( 2010-06-12 ) ( Taormina Film Fest ) June 18, 2010 ( 2010-06-18 ) (United States)'],
#  'Running time': ['103 minutes [1]'],
#  'Country': ['United States'],
#  'Language': ['English'],
#  'Budget': ['$200 million [1]'],
#  'Box office': ['$1.067 billion [1]']}

# %% [markdown]
# #### 2.4. Extracting all the Info-Boxes of all the movies on Disney Movies Wikipedia automatically (Putting it all together)

# %%
# Defining functions to automate the proccess we went through on previous sections 

def get_content_value(row_data):
    if row_data.find("li"):
        return [li.get_text(" ", strip=True).replace("\xa0", " ") for li in row_data.find_all("li")]
    elif row_data.find("br"):
        return [text for text in row_data.stripped_strings]
    else:
        return row_data.get_text(" ", strip=True).replace("\xa0", " ")

def clean_tags(soup):
    for tag in soup.find_all(["sup", "span"]):
        tag.decompose()
        
def get_info_box(url):

    r = requests.get(url)
    soup = bs(r.content)
    info_box = soup.find(class_="infobox vevent")
    info_rows = info_box.find_all("tr")
    
    clean_tags(soup)

    movie_info = {}
    for index, row in enumerate(info_rows):
        if index == 0:
            movie_info['title'] = row.find("th").get_text(" ", strip=True)
        else:
            header = row.find('th')
            if header:
                content_key = row.find("th").get_text(" ", strip=True)
                content_value = get_content_value(row.find("td"))
                movie_info[content_key] = content_value
            
    return movie_info

# %%
#testing the function with a sample link

get_info_box("https://en.wikipedia.org/wiki/One_Little_Indian_(film)")
# Out:
# {'title': 'One Little Indian',
#  'Directed by': 'Bernard McEveety',
#  'Written by': 'Harry Spalding',
#  'Produced by': 'Winston Hibler',
#  'Starring': ['James Garner',
#   'Vera Miles',
#   'Pat Hingle',
#   'Morgan Woodward',
#   'Jodie Foster'],
#  'Cinematography': 'Charles F. Wheeler',
#  'Edited by': 'Robert Stafford',
#  'Music by': 'Jerry Goldsmith',
#  'Production company': 'Walt Disney Productions',
#  'Distributed by': 'Buena Vista Distribution',
#  'Release date': ['June 20, 1973'],
#  'Running time': '90 Minutes',
#  'Country': 'United States',
#  'Language': 'English',
#  'Box office': '$2 million'}

# %%
# defining a function to get all the links on the "list of walt disney pictures film"
# and then get the info box of them

r = requests.get("https://en.wikipedia.org/wiki/List_of_Walt_Disney_Pictures_films")
soup = bs(r.content)
movies = soup.select(".wikitable.sortable i a")

base_path = "https://en.wikipedia.org/"

movie_info_list = []
for index, movie in enumerate(movies):
    if index % 10 == 0:
        print(index)
    try:
        relative_path = movie['href']
        full_path = base_path + relative_path
        title = movie['title']
        
        movie_info_list.append(get_info_box(full_path))
        
    except Exception as e:
        print(movie.get_text())
        print(e)
# Out:
# 0
# 10
# 20
# 30
# 40
# Zorro the Avenger
# 'NoneType' object has no attribute 'find'
# The Sign of Zorro
# 'NoneType' object has no attribute 'find'
# 50
# 60
# 70
# 80
# 90
# 100
# 110
# 120
# True-Life Adventures
# 'NoneType' object has no attribute 'find_all'
# 130
# 140
# The London Connection
# 'NoneType' object has no attribute 'find'
# 150
# 160
# 170
# 180
# 190
# 200
# 210
# 220
# 230
# 240
# 250
# 260
# 270
# 280
# 290
# 300
# 310
# 320
# 330
# 340
# 350
# 360
# 370
# 380
# 390
# 400
# 410
# 420
# 430
# 440
# 450
# Better Nate Than Never
# 'NoneType' object has no attribute 'find_all'

# %%
# checking the length 
# 3 of the movies did not have a format required to be scrapped 
len(movie_info_list)
# Out:
# 449

# %%
# checking a number of items in the list
movie_info_list[300:302]
# Out:
# [{'title': 'Bridge to Terabithia',
#   'Directed by': 'Gábor Csupó',
#   'Screenplay by': ['David L. Paterson', 'Jeff Stockwell'],
#   'Based on': ['Bridge to Terabithia', 'by', 'Katherine Paterson'],
#   'Produced by': ['David L. Paterson', 'Lauren Levine', 'Hal Lieberman'],
#   'Starring': ['Josh Hutcherson',
#    'AnnaSophia Robb',
#    'Bailee Madison',
#    'Robert Patrick',
#    'Zooey Deschanel',
#    'Latham Gaines'],
#   'Cinematography': 'Michael Chapman',
#   'Edited by': 'John Gilbert',
#   'Music by': 'Aaron Zigman',
#   'Production companies': ['Walt Disney Pictures',
#    'Walden Media',
#    'Klasky Csupo'],
#   'Distributed by': ['Buena Vista Pictures Distribution',
#    '(United States)',
#    'Summit Entertainment',
#    '(International)'],
#   'Release date': ['February 16, 2007'],
#   'Running time': '95 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$20–25 million',
#   'Box office': '$137.6 million'},
#  {'title': 'Meet the Robinsons',
#   'Directed by': 'Stephen Anderson',
#   'Screenplay by': ['Jon Bernstein',
#    'Michelle Spitz',
#    'Don Hall',
#    'Nathan Greno',
#    'Aurian Redson',
#    'Joe Mateo',
#    'Stephen Anderson'],
#   'Based on': ['A Day with Wilbur Robinson', 'by', 'William Joyce'],
#   'Produced by': 'Dorothy McKim',
#   'Starring': ['Daniel Hansen',
#    'Jordan Fry',
#    'Wesley Singerman',
#    'Angela Bassett',
#    'Tom Selleck',
#    'Harland Williams',
#    'Laurie Metcalf',
#    'Nicole Sullivan',
#    'Adam West',
#    'Ethan Sandler',
#    'Tom Kenny',
#    'Stephen Anderson'],
#   'Edited by': 'Ellen Keneshea',
#   'Music by': 'Danny Elfman',
#   'Production companies': ['Walt Disney Pictures',
#    'Walt Disney Animation Studios'],
#   'Distributed by': 'Buena Vista Pictures Distribution',
#   'Release date': ['March 23, 2007 (US)', 'March 30, 2007 (UK)'],
#   'Running time': '94 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$150 million',
#   'Box office': '$169.3 million'}]

# %%
# turning the list into a dataframe
df = pd.DataFrame(movie_info_list)

# %%
# checking the content of dataframe
df
# Out:
#                                title       Production company  \
# 0            Academy Award Review of  Walt Disney Productions
# 1    Snow White and the Seven Dwarfs  Walt Disney Productions
# 2                          Pinocchio  Walt Disney Productions
# 3                           Fantasia  Walt Disney Productions
# 4               The Reluctant Dragon  Walt Disney Productions
# ..                               ...                      ...
# 444               The Little Mermaid                      NaN
# 445                           Shrunk                      NaN
# 446     Chip 'n Dale: Rescue Rangers                      NaN
# 447                        Pinocchio                      NaN
# 448               Hollywood Stargirl                      NaN
#
#                                           Release date  \
# 0                                       [May 19, 1937]
# 1       [December 21, 1937 ( Carthay Circle Theatre )]
# 2    [February 7, 1940 ( Center Theatre ), February...
# 3                                  [November 13, 1940]
# 4                                      [June 27, 1941]
# ..                                                 ...
# 444                                                NaN
# 445                                                NaN
# 446                                                NaN
# 447                                                NaN
# 448                                                NaN
#
#                              Running time        Country Language  \
# 0    41 minutes (74 minutes 1966 release)  United States  English
# 1                              83 minutes  United States  English
# 2                              88 minutes  United States  English
# 3                             126 minutes  United States  English
# 4                              74 minutes  United States  English
# ..                                    ...            ...      ...
# 444                                   NaN  United States  English
# 445                                   NaN  United States  English
# 446                                   NaN  United States  English
# 447                                   NaN  United States  English
# 448                                   NaN  United States  English
#
#                                          Box office  \
# 0                                           $45.472
# 1                                      $418 million
# 2                                      $164 million
# 3    $76.4–$83.3 million (United States and Canada)
# 4                      $960,000 (worldwide rentals)
# ..                                              ...
# 444                                             NaN
# 445                                             NaN
# 446                                             NaN
# 447                                             NaN
# 448                                             NaN
#
#                                            Directed by  \
# 0                                                  NaN
# 1    [David Hand, William Cottrell, Wilfred Jackson...
# 2    [Ben Sharpsteen, Hamilton Luske, Bill Roberts,...
# 3    [Samuel Armstrong, James Algar, Bill Roberts, ...
# 4    [Alfred Werker, (live action), Hamilton Luske,...
# ..                                                 ...
# 444                                       Rob Marshall
# 445                                       Joe Johnston
# 446                                     Akiva Schaffer
# 447                                    Robert Zemeckis
# 448                                         Julia Hart
#
#                                             Written by  \
# 0                                                  NaN
# 1    [Ted Sears, Richard Creedon, Otto Englander, D...
# 2                                                  NaN
# 3                                                  NaN
# 4    [Live-action:, Ted Sears, Al Perkins, Larry Cl...
# ..                                                 ...
# 444                                                NaN
# 445                                                NaN
# 446                                                NaN
# 447                                                NaN
# 448                                                NaN
#
#                                               Based on  ...  \
# 0                                                  NaN  ...
# 1                 [Snow White, by The, Brothers Grimm]  ...
# 2     [The Adventures of Pinocchio, by, Carlo Collodi]  ...
# 3                                                  NaN  ...
# 4                                                  NaN  ...
# ..                                                 ...  ...
# 444  [Disney, 's, The Little Mermaid, by, Ron Cleme...  ...
# 445  [Characters, by, Stuart Gordon, ,, Brian Yuzna...  ...
# 446  [Chip 'n Dale: Rescue Rangers, by, Tad Stones,...  ...
# 447  [Disney, 's, Pinocchio, The Adventures of Pino...  ...
# 448                                                NaN  ...
#
#                       Screenplay by Countries  \
# 0                               NaN       NaN
# 1                               NaN       NaN
# 2                               NaN       NaN
# 3                               NaN       NaN
# 4                               NaN       NaN
# ..                              ...       ...
# 444     [Jane Goldman, David Magee]       NaN
# 445                  Todd Rosenberg       NaN
# 446         [Dan Gregor, Doug Mand]       NaN
# 447  [Chris Weitz, Robert Zemeckis]       NaN
# 448   [Jordan Horowitz, Julia Hart]       NaN
#
#                                   Production companies Color process Japanese  \
# 0                                                  NaN           NaN      NaN
# 1                                                  NaN           NaN      NaN
# 2                                                  NaN           NaN      NaN
# 3                                                  NaN           NaN      NaN
# 4                                                  NaN           NaN      NaN
# ..                                                 ...           ...      ...
# 444  [Walt Disney Pictures, Lucamar Productions, Ma...           NaN      NaN
# 445           [Walt Disney Pictures, Mandeville Films]           NaN      NaN
# 446           [Walt Disney Pictures, Mandeville Films]           NaN      NaN
# 447  [Walt Disney Pictures, Depth of Field, ImageMo...           NaN      NaN
# 448               [Walt Disney Pictures, Gotham Group]           NaN      NaN
#
#     Hepburn Adaptation by Animation by Traditional Simplified
# 0       NaN           NaN          NaN         NaN        NaN
# 1       NaN           NaN          NaN         NaN        NaN
# 2       NaN           NaN          NaN         NaN        NaN
# 3       NaN           NaN          NaN         NaN        NaN
# 4       NaN           NaN          NaN         NaN        NaN
# ..      ...           ...          ...         ...        ...
# 444     NaN           NaN          NaN         NaN        NaN
# 445     NaN           NaN          NaN         NaN        NaN
# 446     NaN           NaN          NaN         NaN        NaN
# 447     NaN           NaN          NaN         NaN        NaN
# 448     NaN           NaN          NaN         NaN        NaN
#
# [449 rows x 30 columns]

# %% [markdown]
# #### 2.5. Saving all the scrapped information to a CSV file

# %% [markdown]
# Using the Pandas capabilitis we made a csv file of the dataframe
#
# a part of the CSV file is available in the picture

# %%
df.to_csv("disneyfilms.csv")

# %% [markdown]
# ![](https://i.imgur.com/uoigjZ8.jpg)

# %% [markdown]
# Now we have a file which we can use to further analyze the performance of movies

# %% [markdown]
# ## 3. Ideas for future work
#
# Ideas for future work
# - scraping list of movie Wikipedia pages of other companies
# - Analyzing many factors affecting the performance of movies
# - Scrapping the list of Academy Award winning movies and their pages to check for their performance
